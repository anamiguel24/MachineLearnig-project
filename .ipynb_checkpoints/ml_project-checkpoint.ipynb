# %% [markdown]
# # 1. Import the needed libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from pandas_profiling import ProfileReport
from sklearn.cluster import DBSCAN
from sklearn.linear_model import LogisticRegression, LassoCV, RidgeCV, RidgeClassifier
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import KNNImputer,IterativeImputer
from sklearn.preprocessing import OneHotEncoder,MinMaxScaler,StandardScaler
from sklearn.ensemble import RandomForestClassifier,IsolationForest
from sklearn.feature_selection import mutual_info_classif,RFE,RFECV,SelectKBest, f_classif
from sklearn.neighbors import NearestNeighbors, KNeighborsClassifier
from sklearn.model_selection import train_test_split
import scipy.stats as stats
from scipy.stats import chi2_contingency
from sklearn.metrics import f1_score

# %% [markdown]
# # 2. Import data

# %%
# to read in jupyter
train_demo = pd.read_excel('data/train_demo.xlsx')
train_health = pd.read_excel('data/train_health.xlsx')
train_habits = pd.read_excel('data/train_habits.xlsx') 

test_health = pd.read_excel('data/test_health.xlsx')
test_demo = pd.read_excel('data/test_demo.xlsx')
test_habits = pd.read_excel('data/test_habits.xlsx')

# %%
# to read in kaggle

#train_demo=pd.read_excel('/kaggle/input/the-smith-parasite/train_demo.xlsx')
#train_health=pd.read_excel('/kaggle/input/the-smith-parasite/train_health.xlsx')
#train_habits=pd.read_excel('/kaggle/input/the-smith-parasite/train_habits.xlsx') 

#test_demo=pd.read_excel('/kaggle/input/the-smith-parasite/test_demo.xlsx')
#test_health=pd.read_excel('/kaggle/input/the-smith-parasite/test_health.xlsx')
#test_habits=pd.read_excel('/kaggle/input/the-smith-parasite/test_habits.xlsx')

# %% [markdown]
# # 3. Explore the data

# %%
# training sets
train_habits['PatientID'].equals(other=train_health['PatientID'])  #a confirmar se os patient id coincidem
train_habits['PatientID'].equals(other=train_demo['PatientID'])

# test sets
test_habits['PatientID'].equals(other=test_health['PatientID'])
test_habits['PatientID'].equals(other=test_demo['PatientID'])
# Out:
# True

# %%
# Merging the training sets into a dataframe called 'train_data'
train_data=pd.merge(pd.merge(train_habits,train_health,how='inner',on='PatientID'),train_demo,how='inner',on='PatientID').set_index('PatientID')
train_data
# Out:
#           Smoking_Habit                       Drinking_Habit Exercise  \
# PatientID
# 1167                 No  I usually consume alcohol every day      Yes
# 1805                 No   I consider myself a social drinker      Yes
# 1557                 No   I consider myself a social drinker       No
# 1658                 No  I usually consume alcohol every day      Yes
# 1544                 No   I consider myself a social drinker       No
# ...                 ...                                  ...      ...
# 1909                 No   I consider myself a social drinker      Yes
# 1386                 No  I usually consume alcohol every day       No
# 1088                 No   I consider myself a social drinker       No
# 1662                 No  I usually consume alcohol every day       No
# 1117                 No   I consider myself a social drinker      Yes
#
#                                                Fruit_Habit  \
# PatientID
# 1167       Less than 1. I do not consume fruits every day.
# 1805       Less than 1. I do not consume fruits every day.
# 1557       Less than 1. I do not consume fruits every day.
# 1658       Less than 1. I do not consume fruits every day.
# 1544                     1 to 2 pieces of fruit in average
# ...                                                    ...
# 1909       Less than 1. I do not consume fruits every day.
# 1386       Less than 1. I do not consume fruits every day.
# 1088                     3 to 4 pieces of fruit in average
# 1662       Less than 1. I do not consume fruits every day.
# 1117       Less than 1. I do not consume fruits every day.
#
#                                               Water_Habit  Height  Weight  \
# PatientID
# 1167                     Between one liter and two liters     155      67
# 1805                     Between one liter and two liters     173      88
# 1557       More than half a liter but less than one liter     162      68
# 1658       More than half a liter but less than one liter     180      66
# 1544       More than half a liter but less than one liter     180      58
# ...                                                   ...     ...     ...
# 1909                     Between one liter and two liters     178      61
# 1386                     Between one liter and two liters     157      61
# 1088       More than half a liter but less than one liter     167      48
# 1662       More than half a liter but less than one liter     165      75
# 1117                               Less than half a liter     173      70
#
#            High_Cholesterol  Blood_Pressure  Mental_Health  Physical_Health  \
# PatientID
# 1167                    358             120             21                2
# 1805                    230             142              9                0
# 1557                    226             122             26                0
# 1658                    313             125             13                8
# 1544                    277             125             18                2
# ...                     ...             ...            ...              ...
# 1909                    204             144             12                4
# 1386                    213             120             23                0
# 1088                    272             140             20               17
# 1662                    208             112             16                0
# 1117                    181             120             11               12
#
#                      Checkup  \
# PatientID
# 1167       More than 3 years
# 1805                Not sure
# 1557       More than 3 years
# 1658                Not sure
# 1544       More than 3 years
# ...                      ...
# 1909                Not sure
# 1386       More than 3 years
# 1088       More than 3 years
# 1662       More than 3 years
# 1117                Not sure
#
#                                                     Diabetes  \
# PatientID
# 1167        Neither I nor my immediate family have diabetes.
# 1805        Neither I nor my immediate family have diabetes.
# 1557        Neither I nor my immediate family have diabetes.
# 1658       I have/had pregnancy diabetes or borderline di...
# 1544       I have/had pregnancy diabetes or borderline di...
# ...                                                      ...
# 1909        Neither I nor my immediate family have diabetes.
# 1386       I have/had pregnancy diabetes or borderline di...
# 1088        Neither I nor my immediate family have diabetes.
# 1662        Neither I nor my immediate family have diabetes.
# 1117        Neither I nor my immediate family have diabetes.
#
#                              Name  Birth_Year                    Region  \
# PatientID
# 1167           Mrs. Stephanie Gay        1965                    London
# 1805             Mr. Sherman Nero        1969                South West
# 1557              Mr. Mark Boller        1974  Yorkshire and the Humber
# 1658             Mr. David Caffee        1958                    London
# 1544             Mr. Gerald Emery        1968                South East
# ...                           ...         ...                       ...
# 1909             Mr. Philip Klink        1972             East Midlands
# 1386         Mrs. Jackie Valencia        1980                North West
# 1088           Mrs. Cheryl Harris        1860             East Midlands
# 1662        Mr. Florencio Doherty        1975           East of England
# 1117       Mr. Freddie Vermillion        1979                    London
#
#                                              Education  Disease
# PatientID
# 1167       High School Incomplete (10th to 11th grade)        1
# 1805       High School Incomplete (10th to 11th grade)        1
# 1557              Elementary School (1st to 9th grade)        1
# 1658             University Complete (3 or more years)        0
# 1544              University Incomplete (1 to 2 years)        1
# ...                                                ...      ...
# 1909       High School Incomplete (10th to 11th grade)        0
# 1386              Elementary School (1st to 9th grade)        1
# 1088              Elementary School (1st to 9th grade)        0
# 1662              Elementary School (1st to 9th grade)        1
# 1117              Elementary School (1st to 9th grade)        0
#
# [800 rows x 18 columns]

# %%
# Merging the test sets into a dataframe called 'test_data'
test_data=pd.merge(pd.merge(test_habits,test_health,how='inner',on='PatientID'),test_demo,how='inner',on='PatientID').set_index('PatientID')
test_data
# Out:
#           Smoking_Habit                       Drinking_Habit Exercise  \
# PatientID
# 1343                Yes  I usually consume alcohol every day       No
# 1727                 No   I consider myself a social drinker       No
# 1828                 No  I usually consume alcohol every day      Yes
# 1155                 No  I usually consume alcohol every day       No
# 1020                 No   I consider myself a social drinker       No
# ...                 ...                                  ...      ...
# 1000                 No  I usually consume alcohol every day       No
# 1256                 No  I usually consume alcohol every day       No
# 1318                 No  I usually consume alcohol every day      Yes
# 1953                 No   I consider myself a social drinker      Yes
# 1757                 No   I consider myself a social drinker       No
#
#                                                Fruit_Habit  \
# PatientID
# 1343       Less than 1. I do not consume fruits every day.
# 1727       Less than 1. I do not consume fruits every day.
# 1828       Less than 1. I do not consume fruits every day.
# 1155       Less than 1. I do not consume fruits every day.
# 1020       Less than 1. I do not consume fruits every day.
# ...                                                    ...
# 1000                     3 to 4 pieces of fruit in average
# 1256       Less than 1. I do not consume fruits every day.
# 1318                     1 to 2 pieces of fruit in average
# 1953       Less than 1. I do not consume fruits every day.
# 1757       Less than 1. I do not consume fruits every day.
#
#                                               Water_Habit  Height  Weight  \
# PatientID
# 1343                     Between one liter and two liters     172      80
# 1727       More than half a liter but less than one liter     171      80
# 1828                     Between one liter and two liters     171      78
# 1155                               Less than half a liter     174      87
# 1020                               Less than half a liter     172      56
# ...                                                   ...     ...     ...
# 1000       More than half a liter but less than one liter     178      89
# 1256                               Less than half a liter     154      63
# 1318                     Between one liter and two liters     173      90
# 1953       More than half a liter but less than one liter     155      45
# 1757                     Between one liter and two liters     178      91
#
#            High_Cholesterol  Blood_Pressure  Mental_Health  Physical_Health  \
# PatientID
# 1343                    203             172             20                2
# 1727                    225             130             21                0
# 1828                    237             130             24                1
# 1155                    313             108             19                0
# 1020                    189             140             19               14
# ...                     ...             ...            ...              ...
# 1000                    216             125             22                4
# 1256                    187             138             25                6
# 1318                    181             140             20                0
# 1953                    240             138             18                0
# 1757                    232             160             15               11
#
#                                           Checkup  \
# PatientID
# 1343                                     Not sure
# 1727                                     Not sure
# 1828                            More than 3 years
# 1155                                     Not sure
# 1020                            More than 3 years
# ...                                           ...
# 1000                                     Not sure
# 1256                            More than 3 years
# 1318                                     Not sure
# 1953                            More than 3 years
# 1757       Less than 3 years but more than 1 year
#
#                                                     Diabetes  \
# PatientID
# 1343       I have/had pregnancy diabetes or borderline di...
# 1727                                      I do have diabetes
# 1828       I have/had pregnancy diabetes or borderline di...
# 1155                                      I do have diabetes
# 1020       I have/had pregnancy diabetes or borderline di...
# ...                                                      ...
# 1000        Neither I nor my immediate family have diabetes.
# 1256        Neither I nor my immediate family have diabetes.
# 1318        Neither I nor my immediate family have diabetes.
# 1953        Neither I nor my immediate family have diabetes.
# 1757        Neither I nor my immediate family have diabetes.
#
#                             Name  Birth_Year                    Region  \
# PatientID
# 1343         Mr. Ricardo Sherman        1970             East Midlands
# 1727       Mr. Jessie Strickland        1966  Yorkshire and the Humber
# 1828          Mr. Robert Foreman        1978             West Midlands
# 1155          Mr. Edwin Ferguson        1968  Yorkshire and the Humber
# 1020           Mr. Eliseo Krefft        1962             East Midlands
# ...                          ...         ...                       ...
# 1000           Mr. John Eichhorn        1970             East Midlands
# 1256         Mrs. Tiffany Medley        1987             West Midlands
# 1318           Mr. Kenneth Crase        1963             East Midlands
# 1953         Mrs. Tracy Williams        1977             East Midlands
# 1757            Mr. Chris Hoskin        1956             West Midlands
#
#                                              Education
# PatientID
# 1343              Elementary School (1st to 9th grade)
# 1727             University Complete (3 or more years)
# 1828       High School Incomplete (10th to 11th grade)
# 1155       High School Incomplete (10th to 11th grade)
# 1020       High School Incomplete (10th to 11th grade)
# ...                                                ...
# 1000              University Incomplete (1 to 2 years)
# 1256             University Complete (3 or more years)
# 1318                              High School Graduate
# 1953       High School Incomplete (10th to 11th grade)
# 1757             University Complete (3 or more years)
#
# [225 rows x 17 columns]

# %%
# Generating a profile report to better explore the data
ProfileReport(
    train_data,
    title='The Smith Parasite - Training Data',
    correlations={
        "pearson": {"calculate": True},
        "spearman": {"calculate": True},
        "kendall": {"calculate": False},
        "phi_k": {"calculate": False},
        "cramers": {"calculate": False},
    },                 #há 2 Mr. Gary Miller mas com diferentes dados portanto não é um erro
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 # Generating a profile report to better explore the data
# ----> 2 ProfileReport(
#       3     train_data,
#       4     title='The Smith Parasite - Training Data',
#       5     correlations={
#       6         "pearson": {"calculate": True},
#       7         "spearman": {"calculate": True},
#       8         "kendall": {"calculate": False},
#       9         "phi_k": {"calculate": False},
#      10         "cramers": {"calculate": False},
#      11     },                 #há 2 Mr. Gary Miller mas com diferentes dados portanto não é um erro
#      12 )
#
# NameError: name 'ProfileReport' is not defined

# %%
# There are 2 people with the name 'Mr. Gary Miller', but they have diferent information, so it is not an error
train_data.loc[train_data['Name'] == 'Mr. Gary Miller']
# Out:
#           Smoking_Habit                       Drinking_Habit Exercise  \
# PatientID
# 1221                 No   I consider myself a social drinker       No
# 1694                 No  I usually consume alcohol every day       No
#
#                                                Fruit_Habit  \
# PatientID
# 1221                     1 to 2 pieces of fruit in average
# 1694       Less than 1. I do not consume fruits every day.
#
#                                               Water_Habit  Height  Weight  \
# PatientID
# 1221                               Less than half a liter     172      65
# 1694       More than half a liter but less than one liter     178      61
#
#            High_Cholesterol  Blood_Pressure  Mental_Health  Physical_Health  \
# PatientID
# 1221                    258             130             17                6
# 1694                    223             118             15                5
#
#             Checkup                                          Diabetes  \
# PatientID
# 1221       Not sure  Neither I nor my immediate family have diabetes.
# 1694       Not sure  Neither I nor my immediate family have diabetes.
#
#                       Name  Birth_Year      Region  \
# PatientID
# 1221       Mr. Gary Miller        1959  North West
# 1694       Mr. Gary Miller        1983  South West
#
#                                        Education  Disease
# PatientID
# 1221       University Complete (3 or more years)        0
# 1694             I never attended school / Other        0

# %%
# checking the data type of each column
train_data.dtypes
# Out:
# Smoking_Habit       object
# Drinking_Habit      object
# Exercise            object
# Fruit_Habit         object
# Water_Habit         object
# Height               int64
# Weight               int64
# High_Cholesterol     int64
# Blood_Pressure       int64
# Mental_Health        int64
# Physical_Health      int64
# Checkup             object
# Diabetes            object
# Name                object
# Birth_Year           int64
# Region              object
# Education           object
# Disease              int64
# dtype: object

# %%
train_data.describe().T
# Out:
#                   count        mean        std     min      25%     50%  \
# Height            800.0   167.80625   7.976888   151.0   162.00   167.0
# Weight            800.0    67.82750  12.113470    40.0    58.00    68.0
# High_Cholesterol  800.0   249.32250  51.566631   130.0   213.75   244.0
# Blood_Pressure    800.0   131.05375  17.052693    94.0   120.00   130.0
# Mental_Health     800.0    17.34500   5.385139     0.0    13.00    18.0
# Physical_Health   800.0     4.55875   5.449189     0.0     0.00     3.0
# Birth_Year        800.0  1966.04375  15.421872  1855.0  1961.00  1966.0
# Disease           800.0     0.51375   0.500124     0.0     0.00     1.0
#
#                      75%     max
# Height             173.0   180.0
# Weight              77.0    97.0
# High_Cholesterol   280.0   568.0
# Blood_Pressure     140.0   200.0
# Mental_Health       21.0    29.0
# Physical_Health      7.0    30.0
# Birth_Year        1974.0  1993.0
# Disease              1.0     1.0

# %% [markdown]
# # 4. Preprocessing the data

# %%
# making a copy of 'train_data'
train_data_original=train_data.copy()

# %% [markdown]
# ## 4.1 Inconsistencies/ incoherences

# %%
#estava a pensar começar por tratar os valores que não fazem sentido, depois missing values e a seguir voltar aos outliers
# Correcting the values 'LONDON' to 'London' in the column 'Region'
train_data.replace("LONDON", 'London', inplace=True)

train_data['Region'].unique()
# Out:
# array(['London', 'South West', 'Yorkshire and the Humber', 'South East',
#        'East Midlands', 'West Midlands', 'East of England', 'North West',
#        'North East'], dtype=object)

# %%
# So we assume that all the values that start with '18' are supposed to start with '19'
def birth_replace(x):      #quando fazer feature selection   #considerar como na
    x=str(x)
    if x[0]=='1' and x[1]=='8':
        x=x[0]+'9'+x[2:]
    else:
        x
    return int(x)

# Correcting the column 'Birth_Year', by applying the function created above
train_data['Birth_Year']=train_data['Birth_Year'].apply(birth_replace) #eram somente 12 valores, todos a começar por 18 e com valores excessivos(o mínimo era 141 anos) portanto assumi que antes de 8 queriam colocar 9

# %%
#checkup tem imensos valores com not sure (39%), vale a pena manter a feature?/devemos tratar not sure como missing values, sendo que pode indicar 'negligencia'?
#na for education
#moda não parece bom até porque as categorias têm valores semelhantes
#também não parece fazer muito sentido retirar essas linhas, tendo em conta a perda de informação
#podemos depois testar o modelo com e sem as linhas para ver qual a melhor performance
#estou a fazer assim e não a usar o ordinal encoder porque com o ordinal não consigo escolher qual string fica com qual número

train_data['Education'].unique()
classification_education={'I never attended school / Other':0,'Elementary School (1st to 9th grade)':1,'High School Incomplete (10th to 11th grade)':2,'High School Graduate':3,'University Incomplete (1 to 2 years)':4,'University Complete (3 or more years)':5}
train_data['Education']=train_data['Education'][~train_data['Education'].isnull()].apply(lambda x:classification_education[x]) #manter os na em education

train_data['Diabetes'].unique()
classification_diabetes={'Neither I nor my immediate family have diabetes.':0,"I don't have diabetes, but I have direct family members who have diabetes.":1,'I have/had pregnancy diabetes or borderline diabetes':2,'I do have diabetes':3}
train_data['Diabetes']=train_data['Diabetes'].apply(lambda x:classification_diabetes[x])

train_data['Drinking_Habit'].unique()
classification_drinking={'I do not consume any type of alcohol':0,'I consider myself a social drinker':1,'I usually consume alcohol every day':2}
train_data['Drinking_Habit']=train_data['Drinking_Habit'].apply(lambda x:classification_drinking[x])

train_data['Fruit_Habit'].unique()
classification_fruit={'Less than 1. I do not consume fruits every day.':0,'1 to 2 pieces of fruit in average':1,'3 to 4 pieces of fruit in average':2,'5 to 6 pieces of fruit in average':3,'More than six pieces of fruit':4} #perguntar à professora sobre valores
train_data['Fruit_Habit']=train_data['Fruit_Habit'].apply(lambda x:classification_fruit[x])

train_data['Water_Habit'].unique()
classification_water={'Less than half a liter':0,'More than half a liter but less than one liter':1,'Between one liter and two liters':2}
train_data['Water_Habit']=train_data['Water_Habit'].apply(lambda x:classification_water[x])

# %%
oenc=OneHotEncoder(drop='first',sparse=False)        #because of 'not sure' i put here also checkup
onehot_features=['Smoking_Habit','Exercise','Region','Checkup']         #very high correlation for checkup so I changed the values of not sure to more than 3 years (also it makes intuitive sense)            

#this way we don't lose the ordering information and we reduce the number of variables
#train_data['Checkup'].replace('Not sure','More than 3 years',inplace=True)
#train_data['Checkup'].drop_duplicates().values
#classification_checkup={'Less than three months':0,'Less than 3 years but more than 1 year':1,'More than 3 years':2}
#train_data['Checkup']=train_data['Checkup'].apply(lambda x:classification_checkup[x])
#onehot_features=['Smoking_Habit','Exercise','Region']       

ohc_feat = oenc.fit_transform(train_data[onehot_features])
ohc_feat_names = oenc.get_feature_names_out()
ohc_df = pd.DataFrame(data=ohc_feat,columns=ohc_feat_names)
ohc_df.index=train_data.index
train_data = pd.concat([train_data.drop(columns=onehot_features), ohc_df], axis=1)

# %%
#checkup not sure and checkup more than 3 years have a negative correlation of 0.86
#checkup not sure -0.457836 correlation with disease more than 3 years 0.519570 the other ones have less than 0.1 absolute value correlation
#so I converted back to dummy variables

# %%
train_data.columns
# Out:
# Index(['Drinking_Habit', 'Fruit_Habit', 'Water_Habit', 'Height', 'Weight',
#        'High_Cholesterol', 'Blood_Pressure', 'Mental_Health',
#        'Physical_Health', 'Diabetes', 'Name', 'Birth_Year', 'Education',
#        'Disease', 'Smoking_Habit_Yes', 'Exercise_Yes',
#        'Region_East of England', 'Region_London', 'Region_North East',
#        'Region_North West', 'Region_South East', 'Region_South West',
#        'Region_West Midlands', 'Region_Yorkshire and the Humber',
#        'Checkup_Less than three months', 'Checkup_More than 3 years',
#        'Checkup_Not sure'],
#       dtype='object')

# %% [markdown]
# ## 4.2 Creating Variables

# %%
#train_data['Name'][train_data['Name'].str.contains('Mrs.')]=0
train_data['Gender'] = [1 if bool('Mrs.' in x) == True else 0 for x in train_data['Name']] #fiz isto pq com o str.contains dava sempre warning
train_data['Age']=datetime.now().year-train_data['Birth_Year']
train_data.drop(columns=['Name','Birth_Year'],inplace=True)  #a coluna Name não dá mais informação relevante

# %%
train_data['BMI']=train_data['Weight']/(train_data['Height']**2)

# %%
train_data.corr()
# Out:
#                                  Drinking_Habit  Fruit_Habit  Water_Habit  \
# Drinking_Habit                         1.000000    -0.124501     0.013454
# Fruit_Habit                           -0.124501     1.000000    -0.000646
# Water_Habit                            0.013454    -0.000646     1.000000
# Height                                -0.029014     0.108593    -0.010371
# Weight                                 0.114506    -0.012834     0.027210
# High_Cholesterol                      -0.181217     0.074567     0.008900
# Blood_Pressure                        -0.140115     0.134733    -0.007879
# Mental_Health                          0.129516    -0.232936     0.022263
# Physical_Health                       -0.174177     0.244280    -0.039717
# Diabetes                               0.168695    -0.221452     0.017727
# Education                              0.037072     0.059988     0.046271
# Disease                                0.209235    -0.394930     0.015691
# Smoking_Habit_Yes                     -0.063029     0.162250     0.054557
# Exercise_Yes                          -0.112796     0.115922    -0.041798
# Region_East of England                 0.059327    -0.053284     0.031497
# Region_London                         -0.010082     0.013046     0.003224
# Region_North East                      0.060039     0.070680    -0.008089
# Region_North West                      0.035126    -0.006180     0.002531
# Region_South East                     -0.042383     0.015504    -0.039454
# Region_South West                      0.015120    -0.004961    -0.024707
# Region_West Midlands                   0.000425     0.019942     0.017129
# Region_Yorkshire and the Humber       -0.040237    -0.022849    -0.002786
# Checkup_Less than three months         0.028537    -0.063751    -0.002190
# Checkup_More than 3 years              0.034173    -0.240498     0.018380
# Checkup_Not sure                      -0.005109     0.211675    -0.012399
# Gender                                -0.018343    -0.113169    -0.060502
# Age                                   -0.177900     0.285609    -0.009221
# BMI                                    0.154903    -0.083483     0.031804
#
#                                    Height    Weight  High_Cholesterol  \
# Drinking_Habit                  -0.029014  0.114506         -0.181217
# Fruit_Habit                      0.108593 -0.012834          0.074567
# Water_Habit                     -0.010371  0.027210          0.008900
# Height                           1.000000  0.512673         -0.091066
# Weight                           0.512673  1.000000         -0.051133
# High_Cholesterol                -0.091066 -0.051133          1.000000
# Blood_Pressure                  -0.018564 -0.094461          0.117339
# Mental_Health                   -0.042378  0.301311          0.002479
# Physical_Health                  0.059302 -0.387060          0.044540
# Diabetes                        -0.065892  0.177475         -0.032797
# Education                       -0.011485 -0.011315         -0.059342
# Disease                         -0.170779  0.175166         -0.075345
# Smoking_Habit_Yes                0.032011 -0.012176          0.020645
# Exercise_Yes                     0.056073 -0.187853          0.038320
# Region_East of England           0.014373  0.026089         -0.041946
# Region_London                   -0.047193 -0.004248          0.085653
# Region_North East               -0.004542  0.018181         -0.027750
# Region_North West               -0.045936 -0.016523          0.054566
# Region_South East                0.041060  0.013975         -0.006733
# Region_South West               -0.008876 -0.028073         -0.035452
# Region_West Midlands            -0.013841 -0.003168         -0.052740
# Region_Yorkshire and the Humber -0.019998 -0.005313          0.002983
# Checkup_Less than three months  -0.068766 -0.037059         -0.062956
# Checkup_More than 3 years       -0.244274  0.092554         -0.003957
# Checkup_Not sure                 0.230323 -0.011470          0.057109
# Gender                          -0.688440 -0.363237          0.193649
# Age                             -0.077296 -0.180501          0.222269
# BMI                             -0.017801  0.845376          0.006442
#
#                                  Blood_Pressure  Mental_Health  \
# Drinking_Habit                        -0.140115       0.129516
# Fruit_Habit                            0.134733      -0.232936
# Water_Habit                           -0.007879       0.022263
# Height                                -0.018564      -0.042378
# Weight                                -0.094461       0.301311
# High_Cholesterol                       0.117339       0.002479
# Blood_Pressure                         1.000000      -0.025034
# Mental_Health                         -0.025034       1.000000
# Physical_Health                        0.158393      -0.333152
# Diabetes                              -0.074798       0.372459
# Education                             -0.051907      -0.062035
# Disease                               -0.166723       0.417867
# Smoking_Habit_Yes                      0.195928       0.002660
# Exercise_Yes                           0.077965      -0.341365
# Region_East of England                -0.027212       0.038246
# Region_London                          0.046858       0.016065
# Region_North East                      0.049703       0.048872
# Region_North West                      0.021280       0.033454
# Region_South East                      0.003227       0.020472
# Region_South West                      0.006949      -0.003354
# Region_West Midlands                   0.010081      -0.066262
# Region_Yorkshire and the Humber       -0.000389      -0.040307
# Checkup_Less than three months        -0.015577      -0.021725
# Checkup_More than 3 years             -0.154887       0.265013
# Checkup_Not sure                       0.111617      -0.179831
# Gender                                 0.074679       0.040531
# Age                                    0.267681      -0.391799
# BMI                                   -0.105768       0.373777
#
#                                  Physical_Health  Diabetes  ...  \
# Drinking_Habit                         -0.174177  0.168695  ...
# Fruit_Habit                             0.244280 -0.221452  ...
# Water_Habit                            -0.039717  0.017727  ...
# Height                                  0.059302 -0.065892  ...
# Weight                                 -0.387060  0.177475  ...
# High_Cholesterol                        0.044540 -0.032797  ...
# Blood_Pressure                          0.158393 -0.074798  ...
# Mental_Health                          -0.333152  0.372459  ...
# Physical_Health                         1.000000 -0.342965  ...
# Diabetes                               -0.342965  1.000000  ...
# Education                               0.042592 -0.053005  ...
# Disease                                -0.441631  0.480804  ...
# Smoking_Habit_Yes                       0.031429 -0.017583  ...
# Exercise_Yes                            0.314121 -0.449419  ...
# Region_East of England                 -0.029610  0.033896  ...
# Region_London                           0.010371  0.046355  ...
# Region_North East                       0.003800  0.001237  ...
# Region_North West                      -0.025439 -0.002074  ...
# Region_South East                      -0.031399 -0.036251  ...
# Region_South West                      -0.076057  0.025477  ...
# Region_West Midlands                    0.045457 -0.040745  ...
# Region_Yorkshire and the Humber        -0.011642 -0.046509  ...
# Checkup_Less than three months         -0.030203 -0.033254  ...
# Checkup_More than 3 years              -0.322061  0.348110  ...
# Checkup_Not sure                        0.269969 -0.305873  ...
# Gender                                 -0.087510  0.083980  ...
# Age                                     0.181875 -0.181159  ...
# BMI                                    -0.486998  0.246362  ...
#
#                                  Region_South East  Region_South West  \
# Drinking_Habit                           -0.042383           0.015120
# Fruit_Habit                               0.015504          -0.004961
# Water_Habit                              -0.039454          -0.024707
# Height                                    0.041060          -0.008876
# Weight                                    0.013975          -0.028073
# High_Cholesterol                         -0.006733          -0.035452
# Blood_Pressure                            0.003227           0.006949
# Mental_Health                             0.020472          -0.003354
# Physical_Health                          -0.031399          -0.076057
# Diabetes                                 -0.036251           0.025477
# Education                                -0.037016          -0.046728
# Disease                                  -0.001265           0.022254
# Smoking_Habit_Yes                         0.007420          -0.040058
# Exercise_Yes                             -0.032259           0.005389
# Region_East of England                   -0.114173          -0.130980
# Region_London                            -0.158435          -0.181757
# Region_North East                        -0.057598          -0.066076
# Region_North West                        -0.096650          -0.110877
# Region_South East                         1.000000          -0.134589
# Region_South West                        -0.134589           1.000000
# Region_West Midlands                     -0.121183          -0.139023
# Region_Yorkshire and the Humber          -0.101003          -0.115871
# Checkup_Less than three months            0.017487          -0.034158
# Checkup_More than 3 years                 0.024162          -0.010153
# Checkup_Not sure                         -0.048154          -0.020555
# Gender                                   -0.060622          -0.012602
# Age                                      -0.004240           0.033247
# BMI                                      -0.000531          -0.030932
#
#                                  Region_West Midlands  \
# Drinking_Habit                               0.000425
# Fruit_Habit                                  0.019942
# Water_Habit                                  0.017129
# Height                                      -0.013841
# Weight                                      -0.003168
# High_Cholesterol                            -0.052740
# Blood_Pressure                               0.010081
# Mental_Health                               -0.066262
# Physical_Health                              0.045457
# Diabetes                                    -0.040745
# Education                                    0.056226
# Disease                                      0.026058
# Smoking_Habit_Yes                           -0.001401
# Exercise_Yes                                -0.003128
# Region_East of England                      -0.117934
# Region_London                               -0.163654
# Region_North East                           -0.059495
# Region_North West                           -0.099834
# Region_South East                           -0.121183
# Region_South West                           -0.139023
# Region_West Midlands                         1.000000
# Region_Yorkshire and the Humber             -0.104330
# Checkup_Less than three months              -0.030756
# Checkup_More than 3 years                    0.002182
# Checkup_Not sure                            -0.005787
# Gender                                       0.015211
# Age                                          0.012588
# BMI                                          0.001788
#
#                                  Region_Yorkshire and the Humber  \
# Drinking_Habit                                         -0.040237
# Fruit_Habit                                            -0.022849
# Water_Habit                                            -0.002786
# Height                                                 -0.019998
# Weight                                                 -0.005313
# High_Cholesterol                                        0.002983
# Blood_Pressure                                         -0.000389
# Mental_Health                                          -0.040307
# Physical_Health                                        -0.011642
# Diabetes                                               -0.046509
# Education                                              -0.009982
# Disease                                                 0.010325
# Smoking_Habit_Yes                                       0.048415
# Exercise_Yes                                           -0.020774
# Region_East of England                                 -0.098295
# Region_London                                          -0.136401
# Region_North East                                      -0.049588
# Region_North West                                      -0.083209
# Region_South East                                      -0.101003
# Region_South West                                      -0.115871
# Region_West Midlands                                   -0.104330
# Region_Yorkshire and the Humber                         1.000000
# Checkup_Less than three months                         -0.025634
# Checkup_More than 3 years                               0.015522
# Checkup_Not sure                                       -0.009069
# Gender                                                  0.021419
# Age                                                     0.034325
# BMI                                                     0.006724
#
#                                  Checkup_Less than three months  \
# Drinking_Habit                                         0.028537
# Fruit_Habit                                           -0.063751
# Water_Habit                                           -0.002190
# Height                                                -0.068766
# Weight                                                -0.037059
# High_Cholesterol                                      -0.062956
# Blood_Pressure                                        -0.015577
# Mental_Health                                         -0.021725
# Physical_Health                                       -0.030203
# Diabetes                                              -0.033254
# Education                                             -0.077653
# Disease                                               -0.031379
# Smoking_Habit_Yes                                      0.120820
# Exercise_Yes                                           0.062240
# Region_East of England                                -0.028976
# Region_London                                          0.035837
# Region_North East                                     -0.014618
# Region_North West                                      0.030904
# Region_South East                                      0.017487
# Region_South West                                     -0.034158
# Region_West Midlands                                  -0.030756
# Region_Yorkshire and the Humber                       -0.025634
# Checkup_Less than three months                         1.000000
# Checkup_More than 3 years                             -0.093477
# Checkup_Not sure                                      -0.069508
# Gender                                                 0.007307
# Age                                                   -0.020580
# BMI                                                    0.001738
#
#                                  Checkup_More than 3 years  Checkup_Not sure  \
# Drinking_Habit                                    0.034173         -0.005109
# Fruit_Habit                                      -0.240498          0.211675
# Water_Habit                                       0.018380         -0.012399
# Height                                           -0.244274          0.230323
# Weight                                            0.092554         -0.011470
# High_Cholesterol                                 -0.003957          0.057109
# Blood_Pressure                                   -0.154887          0.111617
# Mental_Health                                     0.265013         -0.179831
# Physical_Health                                  -0.322061          0.269969
# Diabetes                                          0.348110         -0.305873
# Education                                        -0.037630          0.041281
# Disease                                           0.519570         -0.457836
# Smoking_Habit_Yes                                -0.117316          0.045373
# Exercise_Yes                                     -0.328216          0.283632
# Region_East of England                            0.034257         -0.018794
# Region_London                                     0.074920         -0.047014
# Region_North East                                -0.073534          0.069267
# Region_North West                                -0.054078          0.058735
# Region_South East                                 0.024162         -0.048154
# Region_South West                                -0.010153         -0.020555
# Region_West Midlands                              0.002182         -0.005787
# Region_Yorkshire and the Humber                   0.015522         -0.009069
# Checkup_Less than three months                   -0.093477         -0.069508
# Checkup_More than 3 years                         1.000000         -0.859823
# Checkup_Not sure                                 -0.859823          1.000000
# Gender                                            0.354216         -0.298065
# Age                                              -0.102795          0.089929
# BMI                                               0.257173         -0.156064
#
#                                    Gender       Age       BMI
# Drinking_Habit                  -0.018343 -0.177900  0.154903
# Fruit_Habit                     -0.113169  0.285609 -0.083483
# Water_Habit                     -0.060502 -0.009221  0.031804
# Height                          -0.688440 -0.077296 -0.017801
# Weight                          -0.363237 -0.180501  0.845376
# High_Cholesterol                 0.193649  0.222269  0.006442
# Blood_Pressure                   0.074679  0.267681 -0.105768
# Mental_Health                    0.040531 -0.391799  0.373777
# Physical_Health                 -0.087510  0.181875 -0.486998
# Diabetes                         0.083980 -0.181159  0.246362
# Education                       -0.022639 -0.024378 -0.002506
# Disease                          0.289309 -0.212952  0.310558
# Smoking_Habit_Yes               -0.018489  0.116748 -0.036437
# Exercise_Yes                    -0.133372  0.056491 -0.253635
# Region_East of England          -0.014619 -0.051346  0.021427
# Region_London                    0.103623  0.029879  0.024735
# Region_North East               -0.041734  0.030655  0.021746
# Region_North West                0.048189  0.018178  0.008554
# Region_South East               -0.060622 -0.004240 -0.000531
# Region_South West               -0.012602  0.033247 -0.030932
# Region_West Midlands             0.015211  0.012588  0.001788
# Region_Yorkshire and the Humber  0.021419  0.034325  0.006724
# Checkup_Less than three months   0.007307 -0.020580  0.001738
# Checkup_More than 3 years        0.354216 -0.102795  0.257173
# Checkup_Not sure                -0.298065  0.089929 -0.156064
# Gender                           1.000000  0.132151 -0.003986
# Age                              0.132151  1.000000 -0.160002
# BMI                             -0.003986 -0.160002  1.000000
#
# [28 rows x 28 columns]

# %%
train_data.drop(columns='Weight',inplace=True) #due to weight and bmi, the same underlying effect would be applied twice 
#so we remove the variable to prepare for the algorithms to impute the missing values

# %%
metric_features=['Height','High_Cholesterol','Blood_Pressure','Mental_Health','Physical_Health','Age','BMI']
non_metric_features=['Drinking_Habit', 'Fruit_Habit', 'Water_Habit','Diabetes', 'Education','Smoking_Habit_Yes', 
'Exercise_Yes', 'Region_East of England','Region_London', 'Region_North East', 'Region_North West','Region_South East', 
'Region_South West', 'Region_West Midlands','Region_Yorkshire and the Humber', 'Checkup_Less than three months',
'Checkup_More than 3 years', 'Checkup_Not sure', 'Gender']

# %%
ProfileReport(
    train_data,
    title='Updated | The Smith Parasite - Training Data',
    correlations={
        "pearson": {"calculate": True},
        "spearman": {"calculate": True},
        "kendall": {"calculate": False},
        "phi_k": {"calculate": False},
        "cramers": {"calculate": False},
    },                 
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 ProfileReport(
#       2     train_data,
#       3     title='Updated | The Smith Parasite - Training Data',
#       4     correlations={
#       5         "pearson": {"calculate": True},
#       6         "spearman": {"calculate": True},
#       7         "kendall": {"calculate": False},
#       8         "phi_k": {"calculate": False},
#       9         "cramers": {"calculate": False},
#      10     },
#      11 )
#
# NameError: name 'ProfileReport' is not defined

# %% [markdown]
# ## 4.3 Filling in missing values

# %% [markdown]
# ### 4.3.1 Mode

# %%
train_data_mode=train_data.copy()
train_data_mode['Education'].fillna(value=train_data_mode['Education'].mode().values[0],inplace=True)
train_data_mode.drop(columns='Disease',inplace=True)

# %%
train_data_mode.isna().sum()  #verifying that we don't have any missing values left
# Out:
# Drinking_Habit                     0
# Fruit_Habit                        0
# Water_Habit                        0
# Height                             0
# High_Cholesterol                   0
# Blood_Pressure                     0
# Mental_Health                      0
# Physical_Health                    0
# Diabetes                           0
# Education                          0
# Smoking_Habit_Yes                  0
# Exercise_Yes                       0
# Region_East of England             0
# Region_London                      0
# Region_North East                  0
# Region_North West                  0
# Region_South East                  0
# Region_South West                  0
# Region_West Midlands               0
# Region_Yorkshire and the Humber    0
# Checkup_Less than three months     0
# Checkup_More than 3 years          0
# Checkup_Not sure                   0
# Gender                             0
# Age                                0
# BMI                                0
# dtype: int64

# %% [markdown]
# ### 4.3.2 KNN with weights='uniform'

# %%
filter_na_KNN=(abs(train_data.corr()['Education'])>0.01) #filter the variables with correlation to education higher than 0.01 (abs.)
metric_features_na_KNN=metric_features.copy()
metric_features_na_KNN.remove('BMI')
train_data_KNN=train_data[metric_features_na_KNN]
train_data_KNN['Education']=train_data['Education']
remove_na_knn=train_data['BMI']  #the only metric variable that does not go through
# Out:
# C:\Users\AnaMi\AppData\Local\Temp\ipykernel_9352\1657274205.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data_KNN['Education']=train_data['Education']

# %%
# K-Nearest Neighbor
scaler=MinMaxScaler() #como é para o KNN antes de estandardizar estou a normalizar

scaled_feat=scaler.fit_transform(train_data_KNN[metric_features_na_KNN])
train_data_KNN.loc[:,metric_features_na_KNN]=scaled_feat
# Out:
# C:\Users\AnaMi\AppData\Local\Temp\ipykernel_9352\2948746457.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data_KNN.loc[:,metric_features_na_KNN]=scaled_feat

# %%
train_data_KNN1=train_data_KNN.copy()
imputer = KNNImputer(n_neighbors=5, weights="uniform") 
result = imputer.fit_transform(train_data_KNN1)
train_data_KNN1=pd.DataFrame(result,columns=train_data_KNN1.columns,index=train_data_KNN.index)
train_data_KNN1['Education']=train_data_KNN1['Education'].round() #because education is an ordinal variable
train_data_KNN1=train_data_KNN1.join(remove_na_knn)
train_data_KNN1=train_data_KNN1.join(train_data[non_metric_features].loc[:,np.bitwise_and(train_data[non_metric_features].columns!='Education',train_data[non_metric_features].columns!='Disease')])

# %%
train_data_KNN1.isna().sum()
# Out:
# Height                             0
# High_Cholesterol                   0
# Blood_Pressure                     0
# Mental_Health                      0
# Physical_Health                    0
# Age                                0
# Education                          0
# BMI                                0
# Drinking_Habit                     0
# Fruit_Habit                        0
# Water_Habit                        0
# Diabetes                           0
# Smoking_Habit_Yes                  0
# Exercise_Yes                       0
# Region_East of England             0
# Region_London                      0
# Region_North East                  0
# Region_North West                  0
# Region_South East                  0
# Region_South West                  0
# Region_West Midlands               0
# Region_Yorkshire and the Humber    0
# Checkup_Less than three months     0
# Checkup_More than 3 years          0
# Checkup_Not sure                   0
# Gender                             0
# dtype: int64

# %% [markdown]
# ### 4.3.3 KNN with weights='distance'

# %%
train_data_KNN2=train_data_KNN.copy()
imputer = KNNImputer(n_neighbors=5, weights="distance") 
result = imputer.fit_transform(train_data_KNN2)
train_data_KNN2=pd.DataFrame(result,columns=train_data_KNN2.columns,index=train_data_KNN.index)
train_data_KNN2['Education']=train_data_KNN2['Education'].round() 
train_data_KNN2=train_data_KNN2.join(remove_na_knn)
train_data_KNN2=train_data_KNN2.join(train_data[non_metric_features].loc[:,np.bitwise_and(train_data[non_metric_features].columns!='Education',train_data[non_metric_features].columns!='Disease')])

# %%
train_data_KNN2.isna().sum()
# Out:
# Height                             0
# High_Cholesterol                   0
# Blood_Pressure                     0
# Mental_Health                      0
# Physical_Health                    0
# Age                                0
# Education                          0
# BMI                                0
# Drinking_Habit                     0
# Fruit_Habit                        0
# Water_Habit                        0
# Diabetes                           0
# Smoking_Habit_Yes                  0
# Exercise_Yes                       0
# Region_East of England             0
# Region_London                      0
# Region_North East                  0
# Region_North West                  0
# Region_South East                  0
# Region_South West                  0
# Region_West Midlands               0
# Region_Yorkshire and the Humber    0
# Checkup_Less than three months     0
# Checkup_More than 3 years          0
# Checkup_Not sure                   0
# Gender                             0
# dtype: int64

# %% [markdown]
# ### 4.3.4 Logistic Regression

# %%
filter_na_LR=(abs(train_data.corr()['Education'])>0.055) # filter the variables with correlation to education higher than 0.01 (abs.)
remove_na_LR=train_data[(abs(train_data.corr()['Education'])<0.055)[abs(train_data.corr()['Education'])<0.055].index]
train_data_LR=train_data[filter_na_LR[filter_na_LR].index] #disease is not here as it should not
# needed a stronger filtering in order to converge

# %%
lr=LogisticRegression(max_iter=5000)
imp=IterativeImputer(estimator=lr,max_iter=5000)
train_data_LR=pd.DataFrame(data=imp.fit_transform(train_data_LR),columns=train_data_LR.columns,index=train_data_LR.index)
train_data_LR=train_data_LR.join(remove_na_LR)
train_data_LR.drop(columns='Disease',inplace=True)

# %%
train_data_LR.isna().sum()
# Out:
# Fruit_Habit                        0
# High_Cholesterol                   0
# Mental_Health                      0
# Education                          0
# Smoking_Habit_Yes                  0
# Region_East of England             0
# Region_West Midlands               0
# Checkup_Less than three months     0
# Drinking_Habit                     0
# Water_Habit                        0
# Height                             0
# Blood_Pressure                     0
# Physical_Health                    0
# Diabetes                           0
# Exercise_Yes                       0
# Region_London                      0
# Region_North East                  0
# Region_North West                  0
# Region_South East                  0
# Region_South West                  0
# Region_Yorkshire and the Humber    0
# Checkup_More than 3 years          0
# Checkup_Not sure                   0
# Gender                             0
# Age                                0
# BMI                                0
# dtype: int64

# %% [markdown]
# ### 4.3.5 Random Forest Classifier

# %%
filter_na_RF=(abs(train_data.corr()['Education'])>0.01)
remove_na_RF=train_data[(abs(train_data.corr()['Education'])<0.01)[abs(train_data.corr()['Education'])<0.01].index]
train_data_RF=train_data[filter_na_RF[filter_na_RF].index]
train_data_RF.drop(columns='Disease',inplace=True)
# Out:
# C:\Users\Miguel\AppData\Local\Temp\ipykernel_11028\2870418688.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data_RF.drop(columns='Disease',inplace=True)

# %%
imp_cat = IterativeImputer(estimator=RandomForestClassifier(), initial_strategy='most_frequent',max_iter=100, random_state=10)
train_data_RF=pd.DataFrame(data=imp_cat.fit_transform(train_data_RF),columns=train_data_RF.columns,index=train_data_RF.index)
train_data_RF=train_data_RF.join(remove_na_RF)

# %%
train_data_RF.isna().sum()
# Out:
# Drinking_Habit                     0
# Fruit_Habit                        0
# Water_Habit                        0
# Height                             0
# High_Cholesterol                   0
# Blood_Pressure                     0
# Mental_Health                      0
# Physical_Health                    0
# Diabetes                           0
# Education                          0
# Smoking_Habit_Yes                  0
# Exercise_Yes                       0
# Region_East of England             0
# Region_London                      0
# Region_North West                  0
# Region_South East                  0
# Region_South West                  0
# Region_West Midlands               0
# Checkup_Less than three months     0
# Checkup_More than 3 years          0
# Checkup_Not sure                   0
# Gender                             0
# Age                                0
# Region_North East                  0
# Region_Yorkshire and the Humber    0
# BMI                                0
# dtype: int64

# %% [markdown]
# ## 4.4 Outliers

# %% [markdown]
# ### 4.4.1 Manual

# %%
filters1 = (
    (train_data_RF['High_Cholesterol']<568)
    &
    (train_data_RF['Blood_Pressure']<192)
    &
    (train_data_RF['Physical_Health']<27)
)
train_data_RF1=train_data_RF[filters1]
print('Percentage of data kept after removing outliers:', np.round(train_data_RF1.shape[0] / train_data_original.shape[0], 4))
# Out:
# Percentage of data kept after removing outliers: 0.9838

# %% [markdown]
# ### 4.4.2 IQR

# %%
q25 = train_data_RF.quantile(.25)
q75 = train_data_RF.quantile(.75)
iqr = (q75 - q25)

upper_lim = q75 + 1.5 * iqr    
lower_lim = q25 - 1.5 * iqr

filters2 = []
for metric in metric_features:
    llim = lower_lim[metric]
    ulim = upper_lim[metric]
    filters2.append(train_data_RF[metric].between(llim, ulim, inclusive='both'))

filters2 = pd.Series(np.all(filters2, 0))
filters2.index=train_data_RF.index
train_data_RF2 = train_data_RF.loc[filters2]   
print('Percentage of data kept after removing outliers:', np.round(train_data_RF2.shape[0] / train_data_original.shape[0], 4))
# Out:
# Percentage of data kept after removing outliers: 0.9338

# %% [markdown]
# ### 4.4.3 Manual & IQR

# %%
train_data_RF3=train_data_RF.copy()
train_data_RF3 = train_data_RF3[(filters1 | filters2)]
print('Percentage of data kept after removing outliers:', np.round(train_data_RF3.shape[0] / train_data_original.shape[0], 4))
# Out:
# Percentage of data kept after removing outliers: 0.9838

# %% [markdown]
# ### 4.4.4 Z-Score

# %%
train_data_RF4=train_data_RF.copy()
scaler=StandardScaler() 
scaled_feat=scaler.fit_transform(train_data_RF[metric_features])
train_data_RF4[metric_features]=scaled_feat
for metric in metric_features:
    train_data_RF4=train_data_RF4.loc[train_data_RF4[metric]<3].loc[train_data_RF4[metric]>-3]
print('Percentage of data kept after removing outliers:', np.round(train_data_RF4.shape[0] / train_data_original.shape[0], 4))
# Out:
# Percentage of data kept after removing outliers: 0.9662

# %% [markdown]
# ### 4.4.5 DBSCAN

# %%
train_data_RF5=train_data_RF.copy()

# %%
scaler=MinMaxScaler() 
scaled_feat=scaler.fit_transform(train_data_RF5[metric_features])
train_data_RF5[metric_features]=scaled_feat

# %%
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(train_data_RF5[metric_features])
distances, indices = nbrs.kneighbors(train_data_RF5[metric_features])

# %%
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)
plt.show()

# %%
dbscan = DBSCAN(eps = 0.33, min_samples = 14)
pred = dbscan.fit_predict(train_data_RF5[metric_features])
anom_index = np.where(pred == -1)
train_data_RF5.reset_index(inplace=True)
train_data_RF5.drop(anom_index[0],inplace=True)
train_data_RF5.set_index('PatientID')
print('Percentage of data kept after removing outliers:', np.round(train_data_RF5.shape[0] / train_data_original.shape[0], 4))
# Out:
# Percentage of data kept after removing outliers: 0.8912

# %% [markdown]
# ### 4.4.6 Isolation Forest

# %%
train_data_RF6=train_data_RF.copy()
model=IsolationForest(contamination=0.03) #expected proportion of outliers to be 3%
model.fit(train_data_RF6.values)
anomaly=model.predict(train_data_RF6.values)
anom_index=np.where(anomaly==-1)
train_data_RF6.reset_index(inplace=True)
train_data_RF6.drop(anom_index[0],inplace=True)
train_data_RF6.set_index('PatientID')
print('Percentage of data kept after removing outliers:', np.round(train_data_RF6.shape[0] / train_data_original.shape[0], 4))
# Out:
# Percentage of data kept after removing outliers: 0.97

# %% [markdown]
# ### Analyze the dataset after outlier detection and data imputation

# %%
ProfileReport(
    train_data_RF4,
    title='Analysis after outlier detection and data imputation',
    correlations={
        "pearson": {"calculate": True},
        "spearman": {"calculate": True},
        "kendall": {"calculate": False},
        "phi_k": {"calculate": False},
        "cramers": {"calculate": False},
    },                 
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 ProfileReport(
#       2     train_data_RF4,
#       3     title='Analysis after outlier detection and data imputation',
#       4     correlations={
#       5         "pearson": {"calculate": True},
#       6         "spearman": {"calculate": True},
#       7         "kendall": {"calculate": False},
#       8         "phi_k": {"calculate": False},
#       9         "cramers": {"calculate": False},
#      10     },
#      11 )
#
# NameError: name 'ProfileReport' is not defined

# %% [markdown]
# # 5. Feature Selection

# %%
#x=train_data_RF4.copy()
#y=train_data['Disease'][train_data_RF4.index]

# %%
x=train_data_RF.loc[train_data_RF4.index]
y=train_data['Disease'].loc[train_data_RF4.index]

# %%
#x_train_num = x_train.select_dtypes(include=np.number).set_index(x_train.index)
#x_train_cat = x_train.select_dtypes(exclude=np.number).set_index(x_train.index)
# DO IT for validation
#x_val_num = x_val.select_dtypes(include=np.number).set_index(x_val.index)
#x_val_cat = x_val.select_dtypes(exclude=np.number).set_index(x_val.index)

# %%
# categorical_features = ['Drinking_Habit', 'Fruit_Habit', 'Water_Habit', 'Diabetes', 'Education']
# numeric_features = x_train.drop(categorical_features, axis=1).columns
# # For train
# x_train_num = x_train[numeric_features]
# x_train_cat = x_train[categorical_features]
# # For validation
# x_val_num = x_val[numeric_features]
# x_val_cat = x_val[categorical_features]

# %%
# For train
x_num = x[metric_features]
x_cat = x[non_metric_features]
# For validation
#x_val_num = x_val[metric_features]
#x_val_cat = x_val[non_metric_features]

# %%
scaler_num = MinMaxScaler().fit(x_num)
scaler_cat = MinMaxScaler().fit(x_cat)
x_num_scaled = scaler_num.transform(x_num) # this will return an array
x_cat_scaled = scaler_cat.transform(x_cat) # this will return an array
# Convert the array to a pandas dataframe
x_num_scaled = pd.DataFrame(x_num_scaled, columns = x_num.columns).set_index(x.index)
x_cat_scaled = pd.DataFrame(x_cat_scaled, columns = x_cat.columns).set_index(x.index)
x_num_scaled.head(3)
# Out:
#              Height  High_Cholesterol  Blood_Pressure  Mental_Health  \
# PatientID
# 1167       0.137931          0.850746        0.302326       0.692308
# 1805       0.758621          0.373134        0.558140       0.230769
# 1557       0.379310          0.358209        0.325581       0.884615
#
#            Physical_Health       Age       BMI
# PatientID
# 1167                   0.1  0.583333  0.830206
# 1805                   0.0  0.500000  0.945490
# 1557                   0.0  0.395833  0.679802

# %%
#x_val_num_scaled = scaler_num.transform(x_val_num)
#x_val_num_scaled = pd.DataFrame(x_val_num_scaled, columns = x_val_num.columns).set_index(x_val.index)
#x_val_cat_scaled = scaler_cat.transform(x_val_cat)
#x_val_cat_scaled = pd.DataFrame(x_val_cat_scaled, columns = x_val_cat.columns).set_index(x_val.index)
#x_val_num_scaled.head(3)
# Out:
#              Height  High_Cholesterol  Blood_Pressure  Mental_Health  \
# PatientID
# 1354       0.931034          0.503731        0.348837       0.500000
# 1713       0.000000          0.373134        0.651163       0.230769
# 1597       0.758621          0.182836        0.511628       0.769231
#
#            Physical_Health       Age       BMI
# PatientID
# 1354                  0.05  0.583333  0.917631
# 1713                  0.60  0.770833  0.076564
# 1597                  0.00  0.187500  0.843810

# %% [markdown]
# ## 5.1 Filter Methods

# %% [markdown]
# ### 5.1.1 Spearman Correlation

# %%
all_train_num = x_num_scaled.join(y)

# function to plot the correlation between the variables
def cor_heatmap(cor):
    plt.figure(figsize=(10,8))
    sns.heatmap(data = cor, annot = True, cmap = plt.cm.Reds, fmt='.1')
    plt.show()
    
# ver aula de data mining para melhorar o gráfico

# %%
cor_spearman = all_train_num.corr(method='spearman')
cor_spearman
# Out:
#                     Height  High_Cholesterol  Blood_Pressure  Mental_Health  \
# Height            1.000000         -0.032990       -0.005377      -0.052424
# High_Cholesterol -0.032990          1.000000        0.140321      -0.031709
# Blood_Pressure   -0.005377          0.140321        1.000000      -0.036877
# Mental_Health    -0.052424         -0.031709       -0.036877       1.000000
# Physical_Health   0.070651          0.006282        0.127912      -0.406320
# Age              -0.049759          0.194628        0.292921      -0.386411
# BMI              -0.026362          0.031304       -0.089201       0.378141
# Disease          -0.160535         -0.102971       -0.125605       0.423005
#
#                   Physical_Health       Age       BMI   Disease
# Height                   0.070651 -0.049759 -0.026362 -0.160535
# High_Cholesterol         0.006282  0.194628  0.031304 -0.102971
# Blood_Pressure           0.127912  0.292921 -0.089201 -0.125605
# Mental_Health           -0.406320 -0.386411  0.378141  0.423005
# Physical_Health          1.000000  0.231273 -0.498236 -0.428797
# Age                      0.231273  1.000000 -0.147062 -0.230580
# BMI                     -0.498236 -0.147062  1.000000  0.300753
# Disease                 -0.428797 -0.230580  0.300753  1.000000

# %%
cor_heatmap(cor_spearman)

# %%
# Tirar conclusões!!!!!!!!

# %% [markdown]
# ### 5.1.2 (Univariate variables) Variance of the independent variables

# %%
#no quasi-constant features
x_num_scaled.var()  #find way to check for categorical variables

# %%
#x_val_num_scaled.var()

# %% [markdown]
# There is no numeric variable that is univariate (variance = 0), so we don't need to drop anything.

# %% [markdown]
# ### 5.1.3 ANOVA

# %%
x_num_scaled.shape
# Out:
# (773, 7)

# %%
selector = SelectKBest(f_classif, k="all") # Create an SelectKBest object to select features according to the k (in this case all) 
                                           # highest scores with best ANOVA F-Values (f_classif) 
X_kBest = selector.fit_transform(x_num_scaled, y)  # We get a transformed version by SelectKBest 
X_kBest.shape
# Out:
# (773, 7)

# %%
# Scores of features - value of the f statistics
selector.scores_
# Out:
# array([ 16.82041173,   5.54587529,  15.82391854, 103.96608392,
#        151.52638243,  27.39502838,  51.93778323])

# %%
# return an array with the integer index of the features selected
cols = selector.get_support(indices=True)
cols
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=int64)

# %%
# decidir com quantas queremos ficar, as com o score mais baixo talvez não seja necessario
features_to_keep = x_num_scaled.iloc[:,cols]
features_to_keep.columns

# %% [markdown]
# ### 5.1.4 Kendall's

# %%
cor_kendall = all_train_num.corr(method='kendall')
cor_kendall

# %%
cor_heatmap(cor_kendall)

# %%
# Tirar conclusões

# %% [markdown]
# ### 5.1.5 Chi-Squared

# %%
# Create a function named TestIndependence that receive as arguments our dataset of independent variables, the target, 
# the name of each independent variable and the alpha defined
# This function will follow the steps of chi-square to check if a independent variable is an important predictor

def TestIndependence(X,y,var,alpha=0.05):        
    dfObserved = pd.crosstab(y,X)  # crosstab() compute a simple cross tabulation of two (or more) factor
                                      # By default, computes a frequency table of the factors
    chi2, p, dof, expected = stats.chi2_contingency(dfObserved.values)   # This function computes the chi-square statistic and p-value
                                                                         # for the hypothesis test of independence of the observed frequencies in the contingency table 
    dfExpected = pd.DataFrame(expected, columns=dfObserved.columns, index = dfObserved.index)
    if p<alpha:    # Here we are analysing the p-value, if it's less than alpha, then we don't reject, which means that that variable is an important predictor
        result="{0} is IMPORTANT for Prediction".format(var)
    else:
        result="{0} is NOT an important predictor. (Discard {0} from model)".format(var)
    print(result)

# %%
for var in x_train_cat:
    TestIndependence(x_cat[var],y, var)

# %% [markdown]
# ## 5.2 Wrapper Methods

# %% [markdown]
# ### 5.2.1 Recursive Feature Elimination with Cross Validation (RFECV) using Logistic Regression

# %%
model = LogisticRegression(max_iter=1500)

# %%
x_scaled = x_cat_scaled.join(x_num_scaled)

rfecv = RFECV(estimator = model, cv=10)
x_rfecv = rfecv.fit_transform(X=x_scaled, y=y)

# variables that were selected by RFECV as the most "important" ones
selected_features_rfecv = pd.Series(rfecv.support_, index = x_scaled.columns)
selected_features_rfecv
# Out:
# Drinking_Habit                      True
# Fruit_Habit                         True
# Water_Habit                        False
# Diabetes                            True
# Education                          False
# Smoking_Habit_Yes                  False
# Exercise_Yes                        True
# Region_East of England              True
# Region_London                      False
# Region_North East                  False
# Region_North West                  False
# Region_South East                  False
# Region_South West                  False
# Region_West Midlands                True
# Region_Yorkshire and the Humber    False
# Checkup_Less than three months     False
# Checkup_More than 3 years           True
# Checkup_Not sure                    True
# Gender                              True
# Height                              True
# High_Cholesterol                    True
# Blood_Pressure                      True
# Mental_Health                       True
# Physical_Health                     True
# Age                                False
# BMI                                False
# dtype: bool

# %%
# ranking of the variables defined by RFECV
pd.Series(rfecv.ranking_, index = x_scaled.columns)
# Out:
# Drinking_Habit                      1
# Fruit_Habit                         1
# Water_Habit                        10
# Diabetes                            1
# Education                           8
# Smoking_Habit_Yes                   9
# Exercise_Yes                        1
# Region_East of England              1
# Region_London                       5
# Region_North East                   6
# Region_North West                   4
# Region_South East                  12
# Region_South West                  11
# Region_West Midlands                1
# Region_Yorkshire and the Humber    13
# Checkup_Less than three months      2
# Checkup_More than 3 years           1
# Checkup_Not sure                    1
# Gender                              1
# Height                              1
# High_Cholesterol                    1
# Blood_Pressure                      1
# Mental_Health                       1
# Physical_Health                     1
# Age                                 7
# BMI                                 3
# dtype: int32

# %% [markdown]
# ### 5.2.2 Recursive Feature Elimination with Cross Validation (RFECV) using Random Forest

# %%
model = RandomForestClassifier()

# %%
x_train_scaled = x_train_cat_scaled.join(x_num_scaled)

rfecv = RFECV(estimator = model, cv=10)
x_rfecv = rfecv.fit_transform(X=x_scaled, y=y)

# variables that were selected by RFECV as the most "important" ones
selected_features_rfecv = pd.Series(rfecv.support_, index = x_scaled.columns)
selected_features_rfecv

# %%
# ranking of the variables defined by RFECV
pd.Series(rfecv.ranking_, index = x_scaled.columns)

# %% [markdown]
# ## 5.3 Embedded Methods

# %% [markdown]
# ### 5.3.1 Lasso Regression

# %%
# function to plot the importance of the features
def plot_importance(coef,name):
    imp_coef = coef.sort_values()
    plt.figure(figsize=(8,10))
    imp_coef.plot(kind = "barh")
    plt.title("Feature importance using " + name + " Model")
    plt.show()

# %%
lasso_cv = LassoCV().fit(x_num_scaled, y)
coef_num_feat_lasso = pd.Series(lasso_cv.coef_ ,index=x_num_scaled.columns)
coef_num_feat_lasso

# %%
print("Lasso picked " + str(sum(coef_num_feat_lasso != 0)) + " variables and eliminated the other " +  str(sum(coef_num_feat_lasso == 0)) + " variables")

# %%
plot_importance(selected_num_feat_lasso,'Lasso')

# %% [markdown]
# ### 5.3.2 Ridge Regression

# %%
ridge_cv = RidgeCV().fit(X = x_num_scaled, y = y)
coef_num_feat_ridge = pd.Series(ridge_cv.coef_, index = x_num_scaled.columns)
coef_num_feat_ridge

# %%
print("Best score using built-in RidgeCV: %f" %ridge_cv.score(x_num_scaled, y))

# %%
# If we use all the features (num + cat)
# ridge_cv = RidgeCV().fit(X = x_train_scaled, y = y_train)
# coef_feat_ridge = pd.Series(ridge_cv.coef_, index = x_train_scaled.columns)
# coef_feat_ridge
# print("Best score using built-in RidgeCV: %f" %ridge_cv.score(x_train_scaled, y_train))

# %%
plot_importance(selected_num_feat_ridge,'Ridge')

# %% [markdown]
# # 6. Modelling

# %% [markdown]
# ## 6.1. Logistic Regression

# %% [markdown]
# ## 6.2. Naive Bayes

# %% [markdown]
# ## 6.3. Instance Based Learning (KNN Classifier)

# %%
# Create a Nearest Neighbor classifier instance
modelKNN = KNeighborsClassifier()

# %%
x_train_KNN = x_train_num_scaled
x_val_KNN = x_val_num_scaled

# %%
# Identify the optimal number of neighbors to select
numberK_list=np.arange(1,25)
high_score=0
nof=0           # Best number of neighbors
score_list_train =[]
score_list_val =[]
for n in numberK_list:
    # Create the KNN model and fit it to our training data
    model = KNeighborsClassifier(n_neighbors = n).fit(x_train_KNN, y_train)
    
    # Using the model calculate the score of our training and validation data
    score_train = model.score(x_train_KNN, y_train)
    score_val = model.score(x_val_KNN, y_val)
    
    score_list_train.append(score_train)
    score_list_val.append(score_val)
    
    if(score_val > high_score):
        high_score = score_val
        nof = numberK_list[n-1]
print("Best number of neighbors: %d" %nof)
print("Mean accuracy in train with %d neighbors: %f" % (nof, score_list_train[nof-1]))
print("Mean accuracy in validation with %d neighbors: %f" % (nof, high_score))

# %%
# Searching for the optimal number of neighbors through observation
knn_acc = []
for i in range(1,35):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train_KNN, y_train)
    val_score = knn.score(x_val_KNN, y_val)
    train_score = knn.score(x_train_KNN, y_train)
    knn_acc.append((i, val_score ,train_score))
df = pd.DataFrame(knn_acc, columns=['K','Test Score','Train Score']).set_index('K')
print(df)

# %%
def evaluate_model(X,y, model):
    predictions = model.predict(X)  
    return f1_score(y, predictions)

# %%
result = KNeighborsClassifier(n_neighbors = 25).fit(x_train_KNN, y_train)
print('Train: ' + str(evaluate_model(x_train_KNN, y_train, result)) + '\n' + 'Val: ' + str(evaluate_model(x_val_KNN, y_val, result)))

# %% [markdown]
# ## 6.4. Neural Networks (MLP Classifier)

# %% [markdown]
# ## 6.5. Gradient Boosting

# %%
model=GradientBoostingClassifier()
cv=StratifiedKFold()

# %%
# evaluate the model
n_scores = cross_val_score(model, x, y, cv=cv)
#print the performance
print('Mean Accuracy: %.3f (%.3f)' % (np.mean(n_scores), np.std(n_scores)))

# %% [markdown]
# # References

# %% [markdown]
# https://www.numpyninja.com/post/mice-algorithm-to-impute-missing-values-in-a-dataset
# https://towardsdatascience.com/imputing-missing-data-with-simple-and-advanced-techniques-f5c7b157fb87
# https://blog.paperspace.com/anomaly-detection-isolation-forest/
# https://towardsdatascience.com/machine-learning-clustering-dbscan-determine-the-optimal-value-for-epsilon-eps-python-example-3100091cfbc
# https://www.datatechnotes.com/2020/04/anomaly-detection-with-dbscan-in-python.html
